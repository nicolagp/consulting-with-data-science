# %%
import prince
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('../data/LA County Crash Data/joint_data.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\math499\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FATAL'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df['FATAL'] = df['NUMBER_KILLED'] == 0

# %%
famd = prince.FAMD(
    n_components = 8,
    n_iter = 10,
    copy=False,
    engine='auto'
)

# %%
# only take specific columns: "не хуя себе!"
x = df[['LATITUDE','LONGITUDE','POPULATION','LIGHTING','COLLISION_SEVERITY','ROAD_COND_2','PCF_VIOLATION','LOCATION_TYPE',
        'INTERSECTION','WEATHER_1', 'WEATHER_2', 'HIT_AND_RUN', 'COLLISION_TIME', 'FATAL']].dropna()
# labels = x['NUMBER_KILLED']
# x = x.drop('NUMBER_KILLED', axis='columns')

# %%
famd = famd.fit(x.drop('FATAL', axis='columns'))

# %%
coords = famd.row_coordinates(x)

# %%
coords
# Out:
#                    0           1            2           3           4  \
# 70056    2090.956714 -266.544932   -28.884700 -155.316643   -2.943021
# 70161    2090.956719 -266.545271   -28.884665 -155.316678   -2.943329
# 70320    2090.956709 -266.544975   -28.884719 -155.316558   -2.942502
# 70571    1839.084912 -426.786289  -431.103252  814.046939  -61.017088
# 71454    2090.956705 -266.544530   -28.884632 -155.316498   -2.942591
# ...              ...         ...          ...         ...         ...
# 1066054  1550.376280 -234.473555   933.337884  -73.335909 -432.205526
# 1066071  1669.523477  859.717359   909.847370  300.078217 -149.333585
# 1066095  1391.757786  769.020465   665.937180  827.210636 -156.233704
# 1066098  1838.283983 -221.021182  1002.376058  195.429459   60.728819
# 1066104  1838.283960 -221.019361  1002.376241  195.429918   60.729756
#
#                   5           6           7
# 70056   -102.236405   -8.183522   -4.429673
# ...

# %%
x['c1'] = c1
x['c2'] = c2
plt.scatter(c1, c2, c=x['FATAL'])
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
famd.column_correlations(x).describe()
# Out:
#                0          1          2          3          4          5  \
# count  43.000000  43.000000  43.000000  43.000000  43.000000  43.000000
# mean   -0.029444   0.012849  -0.005514   0.006241   0.008990   0.007027
# std     0.235755   0.211708   0.218530   0.235813   0.177990   0.204400
# min    -0.491740  -0.959299  -0.908279  -0.891845  -0.454768  -0.844893
# 25%    -0.102527  -0.007369  -0.020700  -0.017030  -0.011229  -0.024689
# 50%    -0.043518   0.001656  -0.007909   0.002756   0.005594  -0.003539
# 75%    -0.008618   0.036564   0.015086   0.030953   0.018520   0.009974
# max     0.569060   0.844561   0.907556   0.871672   0.799052   0.718723
#
#                6          7
# count  43.000000  43.000000
# mean    0.010419   0.003781
# std     0.183776   0.159322
# min    -0.567075  -0.535614
# 25%    -0.019785  -0.007606
# 50%    -0.000838  -0.001577
# 75%     0.013808   0.010323
# max     0.809802   0.849874
